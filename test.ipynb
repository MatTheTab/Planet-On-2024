# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import re

# %%
df=pd.read_csv('data/TenderResultNotice.csv')

# %%
df.head()
# Out:
#   clientType orderType tenderType          noticeType          noticeNumber  \
# 0        1.5  Services      1.1.1  TenderResultNotice  2023/BZP 00000008/01
# 1        1.5  Services      1.1.1  TenderResultNotice  2023/BZP 00000010/01
# 2      1.1.5  Services    1.4.1.5  TenderResultNotice  2023/BZP 00000022/01
# 3      1.1.2     Works      1.1.1  TenderResultNotice  2023/BZP 00000031/01
# 4        1.4  Services      1.1.1  TenderResultNotice  2023/BZP 00000037/01
#
#            bzpNumber  isTenderAmountBelowEU           publicationDate  \
# 0  2023/BZP 00000008                   True  2023-01-01T16:42:33.371Z
# 1  2023/BZP 00000010                   True  2023-01-01T17:45:19.737Z
# 2  2023/BZP 00000022                   True  2023-01-02T06:04:08.875Z
# 3  2023/BZP 00000031                   True  2023-01-02T06:26:11.022Z
# 4  2023/BZP 00000037                   True  2023-01-02T06:32:06.056Z
#
#                                          orderObject  \
# 0  „Przewóz dzieci przedszkolnych i uczniów szkół...
# 1  Usługi restauracyjne na rzecz uczniów Szkoły P...
# 2  Zimowe utrzymanie obiektów drogowych: chodnikó...
# 3  Remont 5 lokali mieszkalnych zasobu Gminy Miej...
# 4            Świadczenie usług utrzymania czystości.
#
#                                              cpvCode  ...  \
# 0  60100000-9 (Usługi w zakresie transportu drogo...  ...
# 1  55523100-3 (Usługi w zakresie posiłków szkolny...  ...
# 2                    90620000-9 (Usługi odśnieżania)  ...
# 3  45453000-7 (Roboty remontowe i renowacyjne),45...  ...
# 4  90919200-4 (Usługi sprzątania biur),90919100-3...  ...
#
#                                     organizationName organizationCity  \
# 0  Tarnogórski Ośrodek Sportu i Rekreacji Spółka ...  Tarnowskie Góry
# 1  SZKOŁA PODSTAWOWA IM. WANDY CHOTOMSKIEJ W KIEŁ...         Kiełczów
# 2             Miejski Zarząd Ulic i Mostów w Tychach            Tychy
# 3             Zarząd Budynków Komunalnych w Krakowie           Kraków
# 4                     Centrum Projektów Europejskich         Warszawa
#
#   organizationProvince organizationCountry organizationNationalId  \
# 0                 PL24                  PL             6450203947
# 1                 PL02                  PL             9111102754
# 2                 PL24                  PL             6462447307
# 3                 PL12                  PL             6751000311
# 4                 PL14                  PL             7010158887
#
#   organizationId                                          tenderId  \
# 0           9111  ocds-148610-7e74b48f-5f85-11ed-8832-4e4740e186ac
# 1          23977  ocds-148610-0db58845-6b11-11ed-abdb-a69c1593877c
# 2           2801  ocds-148610-e5149d4c-7d37-11ed-b4ea-f64d350121d2
# 3           2769  ocds-148610-406a4c6f-600e-11ed-9171-f6b7c7d59353
# 4           7272  ocds-148610-1ec2c002-7487-11ed-b4ea-f64d350121d2
#
#                                             htmlBody  \
# 0  <html><head><meta charset="UTF-8"><style>body ...
# 1  <html><head><meta charset="UTF-8"><style>body ...
# 2  <html><head><meta charset="UTF-8"><style>body ...
# 3  <html><head><meta charset="UTF-8"><style>body ...
# 4  <html><head><meta charset="UTF-8"><style>body ...
#
#                                          contractors  \
# 0  [{'contractorName': None, 'contractorCity': No...
# 1  [{'contractorName': 'HORYZONTY SMAKU S.C', 'co...
# 2  [{'contractorName': 'BIO-EKOS Sp. z o.o. sp. k...
# 3  [{'contractorName': 'M-BUD Monika Duda', 'cont...
# 4  [{'contractorName': None, 'contractorCity': No...
#
#                                objectId
# 0  08daec17-2e71-d42c-e8e1-8400116e04b1
# 1  08daec1f-f35f-2e95-e8e1-8400116e04b2
# 2  08daec87-2999-2675-e8e1-8400116e04be
# 3  08daec8a-3da8-b869-100a-0600107fa4a8
# 4  08daec8b-1147-5014-100a-0600107fa4ad
#
# [5 rows x 22 columns]

# %%
def remove_none(cont):
    cont=eval(cont)
    return len([x for x in cont if not all(v is None for v in x.values())])

# %%
df['contractors']=df['contractors'].apply(remove_none)

# %%
df.head()
# Out:
#   clientType orderType tenderType          noticeType          noticeNumber  \
# 0        1.5  Services      1.1.1  TenderResultNotice  2023/BZP 00000008/01
# 1        1.5  Services      1.1.1  TenderResultNotice  2023/BZP 00000010/01
# 2      1.1.5  Services    1.4.1.5  TenderResultNotice  2023/BZP 00000022/01
# 3      1.1.2     Works      1.1.1  TenderResultNotice  2023/BZP 00000031/01
# 4        1.4  Services      1.1.1  TenderResultNotice  2023/BZP 00000037/01
#
#            bzpNumber  isTenderAmountBelowEU           publicationDate  \
# 0  2023/BZP 00000008                   True  2023-01-01T16:42:33.371Z
# 1  2023/BZP 00000010                   True  2023-01-01T17:45:19.737Z
# 2  2023/BZP 00000022                   True  2023-01-02T06:04:08.875Z
# 3  2023/BZP 00000031                   True  2023-01-02T06:26:11.022Z
# 4  2023/BZP 00000037                   True  2023-01-02T06:32:06.056Z
#
#                                          orderObject  \
# 0  „Przewóz dzieci przedszkolnych i uczniów szkół...
# 1  Usługi restauracyjne na rzecz uczniów Szkoły P...
# 2  Zimowe utrzymanie obiektów drogowych: chodnikó...
# 3  Remont 5 lokali mieszkalnych zasobu Gminy Miej...
# 4            Świadczenie usług utrzymania czystości.
#
#                                              cpvCode  ...  \
# 0  60100000-9 (Usługi w zakresie transportu drogo...  ...
# 1  55523100-3 (Usługi w zakresie posiłków szkolny...  ...
# 2                    90620000-9 (Usługi odśnieżania)  ...
# 3  45453000-7 (Roboty remontowe i renowacyjne),45...  ...
# 4  90919200-4 (Usługi sprzątania biur),90919100-3...  ...
#
#                                     organizationName organizationCity  \
# 0  Tarnogórski Ośrodek Sportu i Rekreacji Spółka ...  Tarnowskie Góry
# 1  SZKOŁA PODSTAWOWA IM. WANDY CHOTOMSKIEJ W KIEŁ...         Kiełczów
# 2             Miejski Zarząd Ulic i Mostów w Tychach            Tychy
# 3             Zarząd Budynków Komunalnych w Krakowie           Kraków
# 4                     Centrum Projektów Europejskich         Warszawa
#
#   organizationProvince organizationCountry organizationNationalId  \
# 0                 PL24                  PL             6450203947
# 1                 PL02                  PL             9111102754
# 2                 PL24                  PL             6462447307
# 3                 PL12                  PL             6751000311
# 4                 PL14                  PL             7010158887
#
#   organizationId                                          tenderId  \
# 0           9111  ocds-148610-7e74b48f-5f85-11ed-8832-4e4740e186ac
# 1          23977  ocds-148610-0db58845-6b11-11ed-abdb-a69c1593877c
# 2           2801  ocds-148610-e5149d4c-7d37-11ed-b4ea-f64d350121d2
# 3           2769  ocds-148610-406a4c6f-600e-11ed-9171-f6b7c7d59353
# 4           7272  ocds-148610-1ec2c002-7487-11ed-b4ea-f64d350121d2
#
#                                             htmlBody contractors  \
# 0  <html><head><meta charset="UTF-8"><style>body ...           2
# 1  <html><head><meta charset="UTF-8"><style>body ...           1
# 2  <html><head><meta charset="UTF-8"><style>body ...           1
# 3  <html><head><meta charset="UTF-8"><style>body ...           5
# 4  <html><head><meta charset="UTF-8"><style>body ...           1
#
#                                objectId
# 0  08daec17-2e71-d42c-e8e1-8400116e04b1
# 1  08daec1f-f35f-2e95-e8e1-8400116e04b2
# 2  08daec87-2999-2675-e8e1-8400116e04be
# 3  08daec8a-3da8-b869-100a-0600107fa4a8
# 4  08daec8b-1147-5014-100a-0600107fa4ad
#
# [5 rows x 22 columns]

# %%
len(df)
# Out:
# 243843

# %%
df.drop(np.where(df['contractors']==0)[0], inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
len(df)
# Out:
# 201512

# %%
df.drop(columns=['clientType', 'tenderType', 'noticeType', 'noticeNumber', 'publicationDate', 'organizationName', 'organizationCity', 'submittingOffersDate', 'procedureResult', 'organizationProvince', 'organizationCountry', 'organizationNationalId', 'organizationId', 'tenderId', 'objectId'], inplace=True)

# %%
def remove_tags(html):
    soup=BeautifulSoup(html)
    txt=soup.get_text()
    c={}
    txt=list(txt.split())
    pattern=r"(\d+\.\d+\.?\))"
    num_pattern=r"(\d+\.\d+)"
    for x in range(len(txt)):
    
        if txt[x]=='PLN':
            i=x-1

            p=[]
            while True:
                i-=1
                if re.search(pattern, txt[i]) is not None:
                
                    p.append(txt[i])
                    break
            
            t=' '.join(p)
            cand=txt[x-1]
            if '.' in cand:
                
                cand=cand.replace('.','')
            if ',-' in cand:
                cand=cand.replace('-', '0')

            if ',' in cand:
                cand.replace(',','.')
            
            cand=re.findall(num_pattern, cand)
            if len(cand)>0:
                cand=float(cand[0])
                c[t]=cand
            
           

    return c

# %%
df['htmlBody']=df['htmlBody'].apply(remove_tags)
